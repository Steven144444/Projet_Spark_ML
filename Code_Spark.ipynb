# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import *
from pyspark.sql import functions as F
from pyspark.sql.types import *
from pyspark.sql.functions import udf, hour, mean, month, year, to_date
from pyspark.sql.window import Window
from tqdm.notebook import tqdm

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.8/site-packages (4.56.0)

# %%
spark = SparkSession.builder.getOrCreate()

# %%
spark.conf.set('spark.sql.repl.eagerEval.enabled', True)

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://3fc0cb7d14cd:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.0.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# # Schema de données

# %%
schema = StructType() \
    .add("STATION", IntegerType(), False) \
    .add("DATE", TimestampType(), False) \
    .add("SOURCE", IntegerType(), True) \
    .add("LATITUDE", FloatType(), True) \
    .add("LONGITUDE", FloatType(), True) \
    .add("ELEVATION", StringType(), True) \
    .add("NAME", StringType(), True) \
    .add("REPORT_TYPE", StringType(), True) \
    .add("CALL_SIGN", StringType(), True) \
    .add("QUALITY_CONTROL", StringType(), True) \
    .add("WND", StringType(), True) \
    .add("CIG", StringType(), True) \
    .add("VIS", StringType(), True) \
    .add("TMP", StringType(), True) \
    .add("DEW", StringType(), True) \
    .add("SLP", StringType(), True) \
    .add("GA1", StringType(), True) \
    .add("GA2", StringType(), True) \
    .add("GA3", StringType(), True) \
    .add("GA4", StringType(), True) \
    .add("GF1", StringType(), True) \
    .add("MA1", StringType(), True) \
    .add("MW1", StringType(), True) \
    .add("MW2", StringType(), True) \
    .add("MW3", StringType(), True) \
    .add("OC1", StringType(), True) \
    .add("REM", StringType(), True) \
    .add("EQD", StringType(), True)

# %% [markdown]
# # Chargement des données

# %%
# station_2018 = spark.read.load("./data/2018", format="csv", header=True, schema=schema, inferSchema=False)
# station_2018.show()

# %%
cols_of_interest = ("STATION","DATE","SOURCE","LATITUDE","LONGITUDE","ELEVATION","NAME","REPORT_TYPE","CALL_SIGN","QUALITY_CONTROL","WND","CIG","VIS","TMP","DEW","SLP")

all_stations = spark.read.load("./data/*", format="csv", header=True, schema=schema, inferSchema=False).select(*cols_of_interest)

# %%
all_stations
# Out:
# +---------+-------------------+------+--------+---------+---------+---------+-----------+---------+---------------+--------------+-----------+------------+-------+-------+-------+
# |  STATION|               DATE|SOURCE|LATITUDE|LONGITUDE|ELEVATION|     NAME|REPORT_TYPE|CALL_SIGN|QUALITY_CONTROL|           WND|        CIG|         VIS|    TMP|    DEW|    SLP|
# +---------+-------------------+------+--------+---------+---------+---------+-----------+---------+---------------+--------------+-----------+------------+-------+-------+-------+
# |826099999|2008-01-01 00:00:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      FM-15|    KFMH |           V020|280,1,N,0062,1|22000,1,9,N|024140,1,N,1|+0020,1|-0040,1|10170,1|
# |826099999|2008-01-01 00:53:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      FM-15|    KCCR |           V020|100,1,N,0021,1|22000,1,9,N|016093,1,N,1|+9999,9|-0030,1|10231,1|
# |826099999|2008-01-01 00:53:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      FM-16|    KDAL |           V020|360,1,N,0057,1|22000,1,9,N|016093,1,N,1|+9999,9|+9999,9|99999,9|
# |826099999|2008-01-01 01:00:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      FM-15|    KFMH |           V020|270,1,N,0046,1|22000,1,9,N|024140,1,N,1|+0010,1|-0040,1|10181,1|
# |826099999|2008-01-01 01:53:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      AUTO |    KCGI |           V020|300,1,N,0067,1|22000,1,9,N|016093,1,N,1|+0030,1|-0040,1|99999,9|
# |826099999|2008-01-01 01:53:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      FM-15|    KCCR |           V020|100,1,N,0031,1|22000,1,9,N|016093,1,N,1|+9999,9|-0030,1|10229,1|
# |826099999|2008-01-01 02:00:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      FM-15|    KFMH |           V020|270,1,N,0051,1|22000,1,9,N|024140,1,N,1|+0010,1|-0040,1|10192,1|
# |826099999|2008-01-01 02:53:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      AUTO |    KCGI |           V020|280,1,N,0041,1|22000,1,9,N|016093,1,N,1|+0020,1|-0040,1|10190,1|
# |826099999|2008-01-01 02:53:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      FM-15|    KCCR |           V020|080,1,N,0041,1|22000,1,9,N|016093,1,N,1|+9999,9|-0030,1|10231,1|
# |826099999|2008-01-01 03:00:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      SY-MT|    KFMH |           V020|300,1,N,0041,1|22000,1,9,N|016000,1,N,1|+0017,1|-0044,1|10203,1|
# |826099999|2008-01-01 03:53:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      AUTO |    KCGI |           V020|280,1,N,0041,1|22000,1,9,N|016093,1,N,1|+0010,1|-0030,1|10200,1|
# |826099999|2008-01-01 03:53:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      FM-15|    KCCR |           V020|100,1,N,0026,1|22000,1,9,N|016093,1,N,1|+9999,9|-0030,1|10234,1|
# |826099999|2008-01-01 04:00:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      FM-15|    KFMH |           V020|999,9,V,0010,1|22000,1,9,N|024140,1,N,1|-0030,1|-0050,1|10196,1|
# |826099999|2008-01-01 04:53:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      AUTO |    KCGI |           V020|260,1,N,0036,1|22000,1,9,N|016093,1,N,1|+0000,1|-0030,1|10207,1|
# |826099999|2008-01-01 04:53:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      FM-15|    KCCR |           V020|090,1,N,0026,1|22000,1,9,N|016093,1,N,1|+9999,9|-0030,1|10236,1|
# |826099999|2008-01-01 05:00:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      FM-15|    KFMH |           V020|210,1,N,0015,1|22000,1,9,N|024140,1,N,1|-0040,1|-0050,1|10199,1|
# |826099999|2008-01-01 05:53:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      AUTO |    KCGI |           V020|290,1,N,0051,1|22000,1,9,N|016093,1,N,1|+0010,1|-0040,1|10216,1|
# |826099999|2008-01-01 05:53:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      FM-15|    KCCR |           V020|100,1,N,0015,1|22000,1,9,N|016093,1,N,1|+9999,9|-0020,1|10240,1|
# |826099999|2008-01-01 06:00:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      FM-15|    KFMH |           V020|260,1,N,0005,1|22000,1,9,N|024140,1,N,1|-0040,1|-0050,1|10209,1|
# |826099999|2008-01-01 06:53:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      AUTO |    KCGI |           V020|290,1,N,0051,1|22000,1,9,N|016093,1,N,1|+0000,1|-0060,1|10226,1|
# +---------+-------------------+------+--------+---------+---------+---------+-----------+---------+---------------+--------------+-----------+------------+-------+-------+-------+
# only showing top 20 rows

# %%
# Nombre de lignes
all_stations.count()
# Out:
# 9573561

# %% [markdown]
# ## Supprimer les lignes du champ TMP avec des valeurs vides OU des +9999

# %%
all_stations = all_stations.na.drop(how="any", subset=["TMP"]).filter(~all_stations.TMP.contains("+9999"))

# %% [markdown]
# ## Supprimer les lignes du champ ELEVATION avec des valeurs vides OU des +9999

# %%
all_stations = all_stations.na.drop(how="any", subset=["ELEVATION"]).filter(~all_stations.ELEVATION.contains("+9999"))

# %% [markdown]
# ## Supprimer les lignes du champ DEW avec des valeurs vides OU des +9999

# %%
all_stations = all_stations.na.drop(how="any", subset=["DEW"]).filter(~all_stations.DEW.contains("+9999"))

# %%
# Nombre de lignes après le drop
all_stations.count()
# Out:
# 9097319

# %%
# Le schema de données
all_stations.printSchema()
# Out:
# root
#  |-- STATION: integer (nullable = true)
#  |-- DATE: timestamp (nullable = true)
#  |-- SOURCE: integer (nullable = true)
#  |-- LATITUDE: float (nullable = true)
#  |-- LONGITUDE: float (nullable = true)
#  |-- ELEVATION: string (nullable = true)
#  |-- NAME: string (nullable = true)
#  |-- REPORT_TYPE: string (nullable = true)
#  |-- CALL_SIGN: string (nullable = true)
#  |-- QUALITY_CONTROL: string (nullable = true)
#  |-- WND: string (nullable = true)
#  |-- CIG: string (nullable = true)
#  |-- VIS: string (nullable = true)
#  |-- TMP: string (nullable = true)
#  |-- DEW: string (nullable = true)
#  |-- SLP: string (nullable = true)

# %% [markdown]
# ## Split de la colonne température

# %%
@udf(returnType=FloatType())
def extract_tmp(tmp_col: str):
    return int(tmp_col.split(',')[0].lstrip('+')) / 10

all_stations = all_stations.withColumn('temperature', extract_tmp(all_stations['TMP']))

# %% [markdown]
# ## Split de la colonne DEW

# %%
@udf(returnType=FloatType())
def extract_dew(dew_col: str):
    return int(dew_col.split(',')[0].lstrip('+')) / 10

all_stations = all_stations.withColumn('precipitation', extract_dew(all_stations['DEW']))

# %%
all_stations.printSchema()
# Out:
# root
#  |-- STATION: integer (nullable = true)
#  |-- DATE: timestamp (nullable = true)
#  |-- SOURCE: integer (nullable = true)
#  |-- LATITUDE: float (nullable = true)
#  |-- LONGITUDE: float (nullable = true)
#  |-- ELEVATION: string (nullable = true)
#  |-- NAME: string (nullable = true)
#  |-- REPORT_TYPE: string (nullable = true)
#  |-- CALL_SIGN: string (nullable = true)
#  |-- QUALITY_CONTROL: string (nullable = true)
#  |-- WND: string (nullable = true)
#  |-- CIG: string (nullable = true)
#  |-- VIS: string (nullable = true)
#  |-- TMP: string (nullable = true)
#  |-- DEW: string (nullable = true)
#  |-- SLP: string (nullable = true)
#  |-- temperature: float (nullable = true)
#  |-- precipitation: float (nullable = true)

# %% [markdown]
# ## Création du champ season

# %%
@udf(returnType=StringType())
def create_season(month: int):
    if month in [7, 8, 9]:
        season = 'Summer'
    elif month in [10, 11, 12]:
        season = 'Autumn'
    elif month in [1, 2, 3]:
        season = 'Winter'
    else:
        season = 'Spring'
    return season

all_stations = all_stations.withColumn('season', create_season(month("DATE")))

# %%
all_stations.printSchema()
# Out:
# root
#  |-- STATION: integer (nullable = true)
#  |-- DATE: timestamp (nullable = true)
#  |-- SOURCE: integer (nullable = true)
#  |-- LATITUDE: float (nullable = true)
#  |-- LONGITUDE: float (nullable = true)
#  |-- ELEVATION: string (nullable = true)
#  |-- NAME: string (nullable = true)
#  |-- REPORT_TYPE: string (nullable = true)
#  |-- CALL_SIGN: string (nullable = true)
#  |-- QUALITY_CONTROL: string (nullable = true)
#  |-- WND: string (nullable = true)
#  |-- CIG: string (nullable = true)
#  |-- VIS: string (nullable = true)
#  |-- TMP: string (nullable = true)
#  |-- DEW: string (nullable = true)
#  |-- SLP: string (nullable = true)
#  |-- temperature: float (nullable = true)
#  |-- precipitation: float (nullable = true)
#  |-- season: string (nullable = true)

# %%
all_stations
# Out:
# +---------+-------------------+------+--------+---------+---------+---------+-----------+---------+---------------+--------------+-----------+------------+-------+-------+-------+-----------+-------------+------+
# |  STATION|               DATE|SOURCE|LATITUDE|LONGITUDE|ELEVATION|     NAME|REPORT_TYPE|CALL_SIGN|QUALITY_CONTROL|           WND|        CIG|         VIS|    TMP|    DEW|    SLP|temperature|precipitation|season|
# +---------+-------------------+------+--------+---------+---------+---------+-----------+---------+---------------+--------------+-----------+------------+-------+-------+-------+-----------+-------------+------+
# |826099999|2008-01-01 00:00:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      FM-15|    KFMH |           V020|280,1,N,0062,1|22000,1,9,N|024140,1,N,1|+0020,1|-0040,1|10170,1|        2.0|         -4.0|Winter|
# |826099999|2008-01-01 01:00:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      FM-15|    KFMH |           V020|270,1,N,0046,1|22000,1,9,N|024140,1,N,1|+0010,1|-0040,1|10181,1|        1.0|         -4.0|Winter|
# |826099999|2008-01-01 01:53:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      AUTO |    KCGI |           V020|300,1,N,0067,1|22000,1,9,N|016093,1,N,1|+0030,1|-0040,1|99999,9|        3.0|         -4.0|Winter|
# |826099999|2008-01-01 02:00:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      FM-15|    KFMH |           V020|270,1,N,0051,1|22000,1,9,N|024140,1,N,1|+0010,1|-0040,1|10192,1|        1.0|         -4.0|Winter|
# |826099999|2008-01-01 02:53:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      AUTO |    KCGI |           V020|280,1,N,0041,1|22000,1,9,N|016093,1,N,1|+0020,1|-0040,1|10190,1|        2.0|         -4.0|Winter|
# |826099999|2008-01-01 03:00:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      SY-MT|    KFMH |           V020|300,1,N,0041,1|22000,1,9,N|016000,1,N,1|+0017,1|-0044,1|10203,1|        1.7|         -4.4|Winter|
# |826099999|2008-01-01 03:53:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      AUTO |    KCGI |           V020|280,1,N,0041,1|22000,1,9,N|016093,1,N,1|+0010,1|-0030,1|10200,1|        1.0|         -3.0|Winter|
# |826099999|2008-01-01 04:00:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      FM-15|    KFMH |           V020|999,9,V,0010,1|22000,1,9,N|024140,1,N,1|-0030,1|-0050,1|10196,1|       -3.0|         -5.0|Winter|
# |826099999|2008-01-01 04:53:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      AUTO |    KCGI |           V020|260,1,N,0036,1|22000,1,9,N|016093,1,N,1|+0000,1|-0030,1|10207,1|        0.0|         -3.0|Winter|
# |826099999|2008-01-01 05:00:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      FM-15|    KFMH |           V020|210,1,N,0015,1|22000,1,9,N|024140,1,N,1|-0040,1|-0050,1|10199,1|       -4.0|         -5.0|Winter|
# |826099999|2008-01-01 05:53:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      AUTO |    KCGI |           V020|290,1,N,0051,1|22000,1,9,N|016093,1,N,1|+0010,1|-0040,1|10216,1|        1.0|         -4.0|Winter|
# |826099999|2008-01-01 06:00:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      FM-15|    KFMH |           V020|260,1,N,0005,1|22000,1,9,N|024140,1,N,1|-0040,1|-0050,1|10209,1|       -4.0|         -5.0|Winter|
# |826099999|2008-01-01 06:53:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      AUTO |    KCGI |           V020|290,1,N,0051,1|22000,1,9,N|016093,1,N,1|+0000,1|-0060,1|10226,1|        0.0|         -6.0|Winter|
# |826099999|2008-01-01 07:00:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      FM-15|    KFMH |           V020|999,9,C,0000,1|22000,1,9,N|024140,1,N,1|-0030,1|-0050,1|10209,1|       -3.0|         -5.0|Winter|
# |826099999|2008-01-01 07:53:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      AUTO |    KCGI |           V020|300,1,N,0093,1|22000,1,9,N|016093,1,N,1|+0010,1|-0080,1|10233,1|        1.0|         -8.0|Winter|
# |826099999|2008-01-01 08:00:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      FM-15|    KFMH |           V020|999,9,V,0005,1|22000,1,9,N|024140,1,N,1|-0050,1|-0060,1|10216,1|       -5.0|         -6.0|Winter|
# |826099999|2008-01-01 08:53:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      AUTO |    KCGI |           V020|300,1,N,0062,1|22000,1,9,N|016093,1,N,1|-0010,1|-0080,1|10243,1|       -1.0|         -8.0|Winter|
# |826099999|2008-01-01 08:55:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      FM-15|    KFMH |           V020|999,9,V,0015,1|22000,1,9,N|024140,1,N,1|-0060,1|-0060,1|10216,1|       -6.0|         -6.0|Winter|
# |826099999|2008-01-01 09:00:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      FM-12|    KFMH |           V020|310,1,N,0021,1|22000,1,9,N|016000,1,N,1|-0011,1|-0050,1|10219,1|       -1.1|         -5.0|Winter|
# |826099999|2008-01-01 09:53:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      AUTO |    KCGI |           V020|300,1,N,0062,1|22000,1,9,N|016093,1,N,1|-0010,1|-0070,1|10250,1|       -1.0|         -7.0|Winter|
# +---------+-------------------+------+--------+---------+---------+---------+-----------+---------+---------------+--------------+-----------+------------+-------+-------+-------+-----------+-------------+------+
# only showing top 20 rows

# %% [markdown]
# ## Moyenne des températures et des précipitations par année/mois/journée/saison

# %%
# Par année
mean_tmp_dew_by_year = all_stations.groupBy([year("DATE").alias("year")]).agg(F.round(mean("temperature"), 2).alias("mean_tmp"), F.round(mean("precipitation"), 2).alias("mean_dew"))
mean_tmp_dew_by_year = mean_tmp_dew_by_year.sort("year")
mean_tmp_dew_by_year
# Out:
# +----+--------+--------+
# |year|mean_tmp|mean_dew|
# +----+--------+--------+
# |2000|    6.68|     3.4|
# |2002|    4.97|    1.17|
# |2004|    5.13|    1.37|
# |2006|     4.2|    0.06|
# |2008|    3.51|   -0.58|
# |2010|    2.22|   -1.53|
# |2012|    2.64|   -1.06|
# |2014|    2.62|   -1.14|
# |2016|    2.64|   -0.99|
# |2018|    2.03|   -1.54|
# +----+--------+--------+

# %%
# Par mois
mean_tmp_dew_by_month = all_stations.groupBy([year("DATE").alias("year"), month("DATE").alias("month")]).agg(F.round(mean("temperature"), 2).alias("mean_tmp"), F.round(mean("precipitation"), 2).alias("mean_dew"))
mean_tmp_dew_by_month = mean_tmp_dew_by_month.sort("year", "month")
mean_tmp_dew_by_month
# Out:
# +----+-----+--------+--------+
# |year|month|mean_tmp|mean_dew|
# +----+-----+--------+--------+
# |2000|    1|    0.31|   -2.23|
# |2000|    2|    0.36|   -2.22|
# |2000|    3|     1.6|   -2.19|
# |2000|    4|    4.48|    0.74|
# |2000|    5|    9.46|    4.29|
# |2000|    6|   11.58|    7.05|
# |2000|    7|   13.81|   10.12|
# |2000|    8|   13.54|   10.29|
# |2000|    9|   10.82|    7.47|
# |2000|   10|    8.54|    5.97|
# |2000|   11|    4.45|    2.29|
# |2000|   12|    1.08|   -0.86|
# |2002|    1|   -3.67|   -5.72|
# |2002|    2|   -1.82|   -4.29|
# |2002|    3|   -0.97|   -4.54|
# |2002|    4|    4.47|   -0.23|
# |2002|    5|    9.88|    3.41|
# |2002|    6|    14.3|     8.4|
# |2002|    7|   16.26|   11.84|
# |2002|    8|   17.02|   12.04|
# +----+-----+--------+--------+
# only showing top 20 rows

# %% [markdown]
# ## Création du champ 'year'

# %%
all_stations = all_stations.withColumn("year", year(all_stations["DATE"]))
all_stations
# Out:
# +---------+-------------------+------+--------+---------+---------+---------+-----------+---------+---------------+--------------+-----------+------------+-------+-------+-------+-----------+-------------+------+----+
# |  STATION|               DATE|SOURCE|LATITUDE|LONGITUDE|ELEVATION|     NAME|REPORT_TYPE|CALL_SIGN|QUALITY_CONTROL|           WND|        CIG|         VIS|    TMP|    DEW|    SLP|temperature|precipitation|season|year|
# +---------+-------------------+------+--------+---------+---------+---------+-----------+---------+---------------+--------------+-----------+------------+-------+-------+-------+-----------+-------------+------+----+
# |826099999|2008-01-01 00:00:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      FM-15|    KFMH |           V020|280,1,N,0062,1|22000,1,9,N|024140,1,N,1|+0020,1|-0040,1|10170,1|        2.0|         -4.0|Winter|2008|
# |826099999|2008-01-01 01:00:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      FM-15|    KFMH |           V020|270,1,N,0046,1|22000,1,9,N|024140,1,N,1|+0010,1|-0040,1|10181,1|        1.0|         -4.0|Winter|2008|
# |826099999|2008-01-01 01:53:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      AUTO |    KCGI |           V020|300,1,N,0067,1|22000,1,9,N|016093,1,N,1|+0030,1|-0040,1|99999,9|        3.0|         -4.0|Winter|2008|
# |826099999|2008-01-01 02:00:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      FM-15|    KFMH |           V020|270,1,N,0051,1|22000,1,9,N|024140,1,N,1|+0010,1|-0040,1|10192,1|        1.0|         -4.0|Winter|2008|
# |826099999|2008-01-01 02:53:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      AUTO |    KCGI |           V020|280,1,N,0041,1|22000,1,9,N|016093,1,N,1|+0020,1|-0040,1|10190,1|        2.0|         -4.0|Winter|2008|
# |826099999|2008-01-01 03:00:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      SY-MT|    KFMH |           V020|300,1,N,0041,1|22000,1,9,N|016000,1,N,1|+0017,1|-0044,1|10203,1|        1.7|         -4.4|Winter|2008|
# |826099999|2008-01-01 03:53:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      AUTO |    KCGI |           V020|280,1,N,0041,1|22000,1,9,N|016093,1,N,1|+0010,1|-0030,1|10200,1|        1.0|         -3.0|Winter|2008|
# |826099999|2008-01-01 04:00:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      FM-15|    KFMH |           V020|999,9,V,0010,1|22000,1,9,N|024140,1,N,1|-0030,1|-0050,1|10196,1|       -3.0|         -5.0|Winter|2008|
# |826099999|2008-01-01 04:53:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      AUTO |    KCGI |           V020|260,1,N,0036,1|22000,1,9,N|016093,1,N,1|+0000,1|-0030,1|10207,1|        0.0|         -3.0|Winter|2008|
# |826099999|2008-01-01 05:00:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      FM-15|    KFMH |           V020|210,1,N,0015,1|22000,1,9,N|024140,1,N,1|-0040,1|-0050,1|10199,1|       -4.0|         -5.0|Winter|2008|
# |826099999|2008-01-01 05:53:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      AUTO |    KCGI |           V020|290,1,N,0051,1|22000,1,9,N|016093,1,N,1|+0010,1|-0040,1|10216,1|        1.0|         -4.0|Winter|2008|
# |826099999|2008-01-01 06:00:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      FM-15|    KFMH |           V020|260,1,N,0005,1|22000,1,9,N|024140,1,N,1|-0040,1|-0050,1|10209,1|       -4.0|         -5.0|Winter|2008|
# |826099999|2008-01-01 06:53:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      AUTO |    KCGI |           V020|290,1,N,0051,1|22000,1,9,N|016093,1,N,1|+0000,1|-0060,1|10226,1|        0.0|         -6.0|Winter|2008|
# |826099999|2008-01-01 07:00:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      FM-15|    KFMH |           V020|999,9,C,0000,1|22000,1,9,N|024140,1,N,1|-0030,1|-0050,1|10209,1|       -3.0|         -5.0|Winter|2008|
# |826099999|2008-01-01 07:53:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      AUTO |    KCGI |           V020|300,1,N,0093,1|22000,1,9,N|016093,1,N,1|+0010,1|-0080,1|10233,1|        1.0|         -8.0|Winter|2008|
# |826099999|2008-01-01 08:00:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      FM-15|    KFMH |           V020|999,9,V,0005,1|22000,1,9,N|024140,1,N,1|-0050,1|-0060,1|10216,1|       -5.0|         -6.0|Winter|2008|
# |826099999|2008-01-01 08:53:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      AUTO |    KCGI |           V020|300,1,N,0062,1|22000,1,9,N|016093,1,N,1|-0010,1|-0080,1|10243,1|       -1.0|         -8.0|Winter|2008|
# |826099999|2008-01-01 08:55:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      FM-15|    KFMH |           V020|999,9,V,0015,1|22000,1,9,N|024140,1,N,1|-0060,1|-0060,1|10216,1|       -6.0|         -6.0|Winter|2008|
# |826099999|2008-01-01 09:00:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      FM-12|    KFMH |           V020|310,1,N,0021,1|22000,1,9,N|016000,1,N,1|-0011,1|-0050,1|10219,1|       -1.1|         -5.0|Winter|2008|
# |826099999|2008-01-01 09:53:00|     4|     0.0|      0.0|      0.0|WXPOD8270|      AUTO |    KCGI |           V020|300,1,N,0062,1|22000,1,9,N|016093,1,N,1|-0010,1|-0070,1|10250,1|       -1.0|         -7.0|Winter|2008|
# +---------+-------------------+------+--------+---------+---------+---------+-----------+---------+---------------+--------------+-----------+------------+-------+-------+-------+-----------+-------------+------+----+
# only showing top 20 rows

# %% [markdown]
# ## Longitude et latitude par station

# %%
annee = int(input("Quelle année? : "))
longitude_latitude_par_station = all_stations.filter(all_stations.year == annee).groupBy(["STATION"]).agg(mean("LATITUDE").alias("lat"), mean("LONGITUDE").alias("long"))
longitude_latitude_par_station.show()
# Out:
# Quelle année? : 2016
# +----------+-----------------+------------------+
# |   STATION|              lat|              long|
# +----------+-----------------+------------------+
# |1027099999| 69.6500015258789|18.899999618530273|
# | 841899999|              3.0| 131.8000030517578|
# |1037099999|69.38333129882812| 20.28333282470703|
# |1006099999|            78.25|22.816665649414062|
# |1001499999|59.79192352294922| 5.340849876403809|
# |1083099999|70.86666870117188| 29.03333282470703|
# |1068099999|71.01667022705078|25.983333587646484|
# |1046099999| 69.7868423461914|20.959444046020508|
# |1002099999|80.05000305175781|             16.25|
# |1045099999|69.83333587646484|21.883333206176758|
# |1059099999|70.06881713867188| 24.97348976135254|
# |1074099999|71.03333282470703| 27.83333396911621|
# |1082099999| 69.1500015258789|             29.25|
# |1052099999|70.68333435058594|23.683332443237305|
# |1023099999|69.05575561523438|18.540355682373047|
# |1011099999|80.06666564941406|              31.5|
# |1016099999|78.93333435058594|28.899999618530273|
# |1020099999|76.48332977294922|16.549999237060547|
# |1062099999|             76.5|25.066667556762695|
# |1007099999|78.91666412353516|11.933333396911621|
# +----------+-----------------+------------------+
# only showing top 20 rows

# %%
longitude_latitude_par_station.count()
# Out:
# 47

# %%
filtre_norvege = longitude_latitude_par_station.filter(longitude_latitude_par_station.long >= 5).filter(longitude_latitude_par_station.long <= 12).filter(longitude_latitude_par_station.lat >= 57).filter(longitude_latitude_par_station.lat <= 65)
filtre_norvege
# Out:
# +----------+-----------------+-----------------+
# |   STATION|              lat|             long|
# +----------+-----------------+-----------------+
# |1001499999|59.79192352294922|5.340849876403809|
# |1023199999| 64.3499984741211|7.800000190734863|
# +----------+-----------------+-----------------+

# %%
# Par jour, pour l'année choisie et pour une station choisie
num_station = int(input("Quelle station ? : "))
mean_tmp_dew_by_day = all_stations.filter(all_stations.year == annee).filter(all_stations.STATION == num_station).groupBy([to_date("DATE").cast("date").alias("date")]).agg(F.round(mean("temperature"), 2).alias("mean_tmp"), F.round(mean("precipitation"), 2).alias("mean_dew"))
mean_tmp_dew_by_day = mean_tmp_dew_by_day.sort("date")
mean_tmp_dew_by_day.show(365)
# Out:
# Quelle station ? : 1023199999
# +----------+--------+--------+
# |      date|mean_tmp|mean_dew|
# +----------+--------+--------+
# |2016-01-01|    7.35|   -0.94|
# |2016-01-02|    4.67|   -3.06|
# |2016-01-03|    1.25|    -8.5|
# |2016-01-04|   -2.52|  -11.04|
# |2016-01-05|   -0.21|   -6.91|
# |2016-01-06|    0.58|   -3.58|
# |2016-01-07|   -0.83|   -8.59|
# |2016-01-08|   -5.31|  -11.65|
# |2016-01-09|   -2.94|  -12.48|
# |2016-01-10|   -2.83|  -11.02|
# |2016-01-11|    1.81|   -6.35|
# |2016-01-12|   -1.34|   -8.94|
# |2016-01-13|   -1.46|   -9.04|
# |2016-01-14|   -1.96|  -11.64|
# |2016-01-15|   -0.46|  -11.81|
# |2016-01-16|    2.15|   -5.15|
# |2016-01-17|     2.5|   -3.69|
# |2016-01-18|    2.75|   -3.98|
# |2016-01-19|    1.04|   -5.91|
# |2016-01-20|     2.0|   -5.19|
# |2016-01-21|    2.42|   -2.85|
# |2016-01-22|    3.75|   -3.23|
# |2016-01-23|    6.23|    3.58|
# |2016-01-24|    6.76|     4.5|
# |2016-01-25|    7.42|    6.36|
# |2016-01-26|    5.78|   -4.64|
# |2016-01-27|    5.34|   -7.55|
# |2016-01-28|    4.37|   -8.76|
# |2016-01-29|    5.84|   -7.24|
# |2016-01-30|     4.5|  -24.77|
# |2016-01-31|    3.38|  -20.19|
# |2016-02-01|    3.23|  -11.35|
# |2016-02-02|    4.62|   -8.47|
# |2016-02-03|    3.56|   -0.93|
# |2016-02-04|    3.58|   -0.83|
# |2016-02-05|    3.31|   -0.71|
# |2016-02-06|    5.58|     2.4|
# |2016-02-07|    5.77|    1.33|
# |2016-02-08|    6.21|     1.6|
# |2016-02-09|    5.42|     2.6|
# |2016-02-10|    3.83|   -2.58|
# |2016-02-11|    2.33|   -5.48|
# |2016-02-12|    2.52|    -4.5|
# |2016-02-13|    2.04|   -5.02|
# |2016-02-14|    1.94|   -2.06|
# |2016-02-15|     2.0|   -3.76|
# |2016-02-16|    3.15|   -2.24|
# |2016-02-17|    5.81|     2.1|
# |2016-02-18|     3.6|     0.6|
# |2016-02-19|    4.77|   -0.77|
# |2016-02-20|    4.88|   -0.73|
# |2016-02-21|    3.52|     0.1|
# |2016-02-22|    3.67|    -0.7|
# |2016-02-23|    4.25|    0.58|
# |2016-02-24|    4.54|    -0.4|
# |2016-02-25|    4.02|    0.11|
# |2016-02-26|    4.04|    0.17|
# |2016-02-27|    3.71|   -1.08|
# |2016-02-28|    3.81|   -0.69|
# |2016-02-29|    3.73|   -1.19|
# |2016-03-01|    3.85|   -1.34|
# |2016-03-02|     4.6|   -1.45|
# |2016-03-03|    3.21|   -0.98|
# |2016-03-04|    4.96|   -0.38|
# |2016-03-05|    3.38|   -0.21|
# |2016-03-06|    3.53|   -2.21|
# |2016-03-07|    3.44|   -2.88|
# |2016-03-08|    2.77|   -2.65|
# |2016-03-09|    4.45|   -0.55|
# |2016-03-10|     6.0|    2.38|
# |2016-03-11|    5.98|    0.23|
# |2016-03-12|    5.98|    1.31|
# |2016-03-13|    6.98|    6.17|
# |2016-03-14|     7.0|     7.0|
# |2016-03-15|    7.67|    5.48|
# |2016-03-16|    7.04|    3.94|
# |2016-03-17|     6.4|    3.15|
# |2016-03-18|    4.56|   -1.08|
# |2016-03-19|    6.17|    2.23|
# |2016-03-20|     5.6|    1.54|
# |2016-03-21|    4.85|    0.98|
# |2016-03-22|     5.2|     0.2|
# |2016-03-23|    4.17|    -0.2|
# |2016-03-24|    4.08|    1.71|
# |2016-03-25|    5.81|    2.19|
# |2016-03-26|    6.68|    2.62|
# |2016-03-27|     7.5|    3.31|
# |2016-03-28|    7.54|    2.52|
# |2016-03-29|    6.89|    1.64|
# |2016-03-30|    4.15|   -1.47|
# |2016-03-31|    3.19|   -1.81|
# |2016-04-01|    3.48|    0.58|
# |2016-04-02|    5.81|    3.77|
# |2016-04-03|    7.52|    4.33|
# |2016-04-04|    7.63|    3.24|
# |2016-04-05|    7.65|    3.78|
# |2016-04-06|    7.04|    3.02|
# |2016-04-07|    5.69|    0.13|
# |2016-04-08|    5.42|    0.27|
# |2016-04-09|    5.19|    0.96|
# |2016-04-10|    6.48|    3.31|
# |2016-04-11|    7.21|    1.73|
# |2016-04-12|     6.0|    1.66|
# |2016-04-13|    3.79|   -3.96|
# |2016-04-14|    3.15|   -2.42|
# |2016-04-15|    3.46|   -3.37|
# |2016-04-16|    5.66|    1.14|
# |2016-04-17|    4.63|    0.15|
# |2016-04-18|    5.27|    2.71|
# |2016-04-19|     7.1|    1.13|
# |2016-04-20|    5.42|    2.02|
# |2016-04-21|    5.42|   -0.15|
# |2016-04-22|     2.9|   -2.33|
# |2016-04-23|    3.23|   -3.94|
# |2016-04-24|    2.44|   -1.75|
# |2016-04-25|    4.42|   -2.51|
# |2016-04-26|     5.9|   -2.25|
# |2016-04-27|     5.6|    0.15|
# |2016-04-28|    6.38|    1.44|
# |2016-04-29|    7.71|    2.13|
# |2016-04-30|    8.04|    2.96|
# |2016-05-01|    7.38|    3.11|
# |2016-05-02|    8.19|    3.75|
# |2016-05-03|    7.46|    5.04|
# |2016-05-04|    7.65|     3.9|
# |2016-05-05|    9.23|    3.19|
# |2016-05-06|    8.49|    4.51|
# |2016-05-07|    8.06|    5.67|
# |2016-05-08|    7.75|     4.4|
# |2016-05-09|     7.9|    4.33|
# |2016-05-10|    6.96|    1.04|
# |2016-05-11|    7.36|    1.53|
# |2016-05-12|    6.29|    1.25|
# |2016-05-13|    5.43|    0.96|
# |2016-05-14|    6.58|    2.23|
# |2016-05-15|    6.79|     1.9|
# |2016-05-16|    5.31|    1.38|
# |2016-05-17|    4.08|   -0.92|
# |2016-05-18|    4.77|   -2.88|
# |2016-05-19|    5.17|   -1.38|
# |2016-05-20|    7.96|    3.63|
# |2016-05-21|     8.0|    7.22|
# |2016-05-25|    7.45|    1.91|
# |2016-05-26|    9.19|     5.0|
# |2016-05-27|   11.13|    7.79|
# |2016-05-28|   13.29|    7.02|
# |2016-05-29|   12.81|    7.74|
# |2016-05-30|    13.0|    9.69|
# |2016-05-31|    10.1|     9.0|
# |2016-06-01|    8.75|    7.42|
# |2016-06-02|    9.17|     6.6|
# |2016-06-03|     8.9|    4.23|
# |2016-06-04|    8.06|    2.43|
# |2016-06-05|    9.79|    3.08|
# |2016-06-06|   10.63|    5.58|
# |2016-06-07|    8.67|    5.02|
# |2016-06-08|    7.42|    1.92|
# |2016-06-09|    7.29|    1.47|
# |2016-06-10|    9.02|    2.15|
# |2016-06-11|    9.85|    3.64|
# |2016-06-12|     9.0|    2.98|
# |2016-06-13|     9.0|    4.65|
# |2016-06-14|     9.6|    3.17|
# |2016-06-15|    9.36|    4.04|
# |2016-06-16|    9.83|    6.33|
# |2016-06-17|    9.15|     6.1|
# |2016-06-18|    8.04|    5.96|
# |2016-06-19|    8.04|    5.31|
# |2016-06-20|     9.8|    5.89|
# |2016-06-21|   10.38|    9.25|
# |2016-06-22|   12.75|    6.83|
# |2016-06-23|    12.1|     9.9|
# |2016-06-24|   10.83|    9.13|
# |2016-06-25|   11.04|     7.6|
# |2016-06-26|   11.81|    9.04|
# |2016-06-27|   11.47|   10.68|
# |2016-06-28|    11.0|    8.81|
# |2016-06-29|   12.42|    8.69|
# |2016-06-30|   14.09|    9.09|
# |2016-07-01|   12.65|    9.29|
# |2016-07-02|   12.33|    9.31|
# |2016-07-03|    11.0|    9.31|
# |2016-07-04|   11.21|    9.94|
# |2016-07-05|   10.98|    8.54|
# |2016-07-06|   10.89|    7.17|
# |2016-07-07|   10.89|    6.67|
# |2016-07-08|   12.38|    8.94|
# |2016-07-09|   13.48|    7.13|
# |2016-07-10|   12.69|    8.85|
# |2016-07-11|   13.69|   11.38|
# |2016-07-12|   13.13|   11.58|
# |2016-07-13|   12.62|   10.17|
# |2016-07-14|   11.58|    7.44|
# |2016-07-15|   11.31|    7.21|
# |2016-07-16|   12.23|    8.38|
# |2016-07-17|   12.83|    9.67|
# |2016-07-18|    12.6|    6.58|
# |2016-07-19|   13.88|     8.0|
# |2016-07-20|   12.73|   12.31|
# |2016-07-21|    19.4|   12.42|
# |2016-07-22|   14.73|   13.81|
# |2016-07-23|   14.35|   13.52|
# |2016-07-24|   14.46|   13.46|
# |2016-07-25|   14.56|   13.38|
# |2016-07-26|   14.19|   12.44|
# |2016-07-27|   14.96|   11.71|
# |2016-07-28|   14.58|   11.98|
# |2016-07-29|   15.08|   12.02|
# |2016-07-30|   14.25|    12.4|
# |2016-07-31|   13.94|    10.5|
# |2016-08-01|   13.82|   10.89|
# |2016-08-02|   13.26|   11.15|
# |2016-08-03|   14.46|   11.15|
# |2016-08-04|    15.7|   12.61|
# |2016-08-05|   14.48|    9.81|
# |2016-08-06|   13.79|    7.98|
# |2016-08-07|   13.58|   10.21|
# |2016-08-08|    14.9|   11.85|
# |2016-08-09|   12.02|    8.19|
# |2016-08-10|   10.13|    3.96|
# |2016-08-11|   10.25|    4.35|
# |2016-08-12|   11.69|    5.58|
# |2016-08-13|    13.6|    6.69|
# |2016-08-14|   12.65|    5.38|
# |2016-08-15|   12.38|   10.25|
# |2016-08-16|   13.44|    11.0|
# |2016-08-17|    15.0|   11.08|
# |2016-08-18|    14.0|    11.6|
# |2016-08-19|   15.11|   11.72|
# |2016-08-20|   13.77|   11.19|
# |2016-08-21|   14.58|   12.73|
# |2016-08-22|   14.54|   12.58|
# |2016-08-23|   13.52|    9.46|
# |2016-08-24|   12.92|   10.67|
# |2016-08-25|   13.46|    9.73|
# |2016-08-26|    12.9|   10.27|
# |2016-08-27|   12.42|     8.2|
# |2016-08-28|   12.96|     8.6|
# |2016-08-29|   12.23|    8.54|
# |2016-08-30|   11.98|   10.38|
# |2016-08-31|   13.77|    12.4|
# |2016-09-01|   11.94|    9.63|
# |2016-09-02|   11.13|    6.35|
# |2016-09-03|   11.79|   10.31|
# |2016-09-04|   11.67|    5.56|
# |2016-09-05|   11.31|     4.4|
# |2016-09-06|   13.21|   11.31|
# |2016-09-07|    11.4|    9.46|
# |2016-09-08|   12.52|    9.15|
# |2016-09-09|   13.42|   11.77|
# |2016-09-10|   13.44|   10.67|
# |2016-09-11|   11.66|    9.49|
# |2016-09-12|    13.6|    9.75|
# |2016-09-13|   16.13|    8.73|
# |2016-09-14|   11.93|    10.0|
# |2016-09-15|   12.65|     8.4|
# |2016-09-16|   15.94|   12.15|
# |2016-09-17|   13.56|   12.67|
# |2016-09-18|   14.35|   12.83|
# |2016-09-19|    13.0|   11.96|
# |2016-09-20|   11.96|   10.46|
# |2016-09-21|   12.77|   11.92|
# |2016-09-22|   14.08|   12.04|
# |2016-09-23|   13.29|   10.49|
# |2016-09-24|   12.52|    8.78|
# |2016-09-25|   15.27|   10.29|
# |2016-09-26|   13.06|   10.04|
# |2016-09-27|   12.38|    8.94|
# |2016-09-28|   10.33|    7.77|
# |2016-09-29|    9.58|    6.53|
# |2016-09-30|    9.46|    5.13|
# |2016-10-01|    9.19|     3.4|
# |2016-10-02|    9.23|    2.21|
# |2016-10-03|   11.02|    2.69|
# |2016-10-04|   11.32|    7.77|
# |2016-10-05|   11.53|    8.28|
# |2016-10-06|   11.67|    7.85|
# |2016-10-07|   12.44|    8.46|
# |2016-10-08|   10.88|    4.58|
# |2016-10-09|    9.69|    4.06|
# |2016-10-10|   10.19|    5.98|
# |2016-10-11|    10.9|    5.65|
# |2016-10-12|   10.64|    5.32|
# |2016-10-13|    9.87|    5.55|
# |2016-10-14|   11.29|     3.6|
# |2016-10-15|    10.0|     3.7|
# |2016-10-16|   10.38|    5.49|
# |2016-10-17|   10.58|    7.06|
# |2016-10-18|   11.06|     7.0|
# |2016-10-19|   11.81|    6.38|
# |2016-10-20|   10.17|     5.5|
# |2016-10-21|    9.29|    4.33|
# |2016-10-22|    7.75|    2.23|
# |2016-10-23|    7.17|    0.81|
# |2016-10-24|    8.83|    3.31|
# |2016-10-25|    9.81|    4.08|
# |2016-10-26|    9.98|    4.38|
# |2016-10-27|     9.4|    5.71|
# |2016-10-28|    6.96|    2.31|
# |2016-10-29|    8.56|    5.54|
# |2016-10-30|    8.35|    6.19|
# |2016-10-31|    8.81|    5.69|
# |2016-11-01|    7.73|    3.67|
# |2016-11-02|    6.85|    2.46|
# |2016-11-03|    5.63|    1.19|
# |2016-11-04|    3.17|   -3.04|
# |2016-11-05|    2.29|   -2.92|
# |2016-11-06|     0.6|   -5.71|
# |2016-11-07|    -0.9|   -7.31|
# |2016-11-08|   -0.52|   -5.58|
# |2016-11-09|    0.33|   -5.81|
# |2016-11-10|    1.23|   -2.08|
# |2016-11-11|    6.17|    4.25|
# |2016-11-12|    7.48|    2.25|
# |2016-11-13|    7.96|    4.48|
# |2016-11-14|    7.94|    5.25|
# |2016-11-15|     8.1|    5.35|
# |2016-11-16|    7.29|     3.6|
# |2016-11-17|    5.13|    1.79|
# |2016-11-18|    5.02|    0.15|
# |2016-11-19|    5.87|    1.32|
# |2016-11-20|     6.5|    0.15|
# |2016-11-21|    6.21|    0.42|
# |2016-11-22|    5.88|    2.02|
# |2016-11-23|    5.33|    0.77|
# |2016-11-24|    4.83|    1.48|
# |2016-11-25|    8.52|    7.83|
# |2016-11-26|     5.6|     0.4|
# |2016-11-27|    4.42|   -2.46|
# |2016-11-28|    7.06|    3.23|
# |2016-11-29|    6.33|    3.48|
# |2016-11-30|    4.13|   -1.79|
# |2016-12-01|    3.78|    0.49|
# |2016-12-02|    4.83|   -1.17|
# |2016-12-03|    5.69|    3.79|
# |2016-12-04|    8.29|    6.81|
# |2016-12-05|    4.85|   -0.24|
# |2016-12-06|    5.98|    1.94|
# |2016-12-07|    6.83|    5.87|
# |2016-12-08|     7.6|    7.58|
# |2016-12-09|    5.54|    1.88|
# |2016-12-10|    3.17|    -3.1|
# |2016-12-11|    2.04|   -4.88|
# |2016-12-12|    4.58|    1.56|
# |2016-12-13|     7.5|    2.48|
# |2016-12-14|    6.85|     1.6|
# |2016-12-15|    7.73|    5.83|
# |2016-12-16|     8.6|    6.71|
# |2016-12-17|     7.4|    4.63|
# |2016-12-18|    8.35|    7.77|
# |2016-12-19|     8.6|    8.08|
# |2016-12-20|    7.75|    3.31|
# |2016-12-21|    6.83|    2.29|
# |2016-12-22|    4.85|   -0.06|
# |2016-12-23|    5.23|    0.56|
# |2016-12-24|    5.04|     1.5|
# |2016-12-25|     5.9|    2.81|
# |2016-12-26|    4.75|    0.58|
# |2016-12-27|    4.13|   -2.25|
# |2016-12-28|    7.58|    6.02|
# |2016-12-29|    6.52|    4.85|
# |2016-12-30|    6.92|     4.0|
# |2016-12-31|    5.73|    0.38|
# +----------+--------+--------+

# %%
mean_tmp_dew_by_day.count()
# Out:
# 363

# %% [markdown]
# ## Apprentissage

# %%
from pyspark.ml.regression import LinearRegression
from pyspark.ml.feature import VectorAssembler

# Load training data
training = mean_tmp_dew_by_day

vectorAssembler = VectorAssembler(inputCols = ["mean_tmp"], outputCol = 'features')
v_training = vectorAssembler.transform(training)
v_training = v_training.select(['features', 'mean_dew'])
v_training.show(3)
# Out:
# +--------+--------+
# |features|mean_dew|
# +--------+--------+
# |  [7.35]|   -0.94|
# |  [4.67]|   -3.06|
# |  [1.25]|    -8.5|
# +--------+--------+
# only showing top 3 rows

# %%
splits = v_training.randomSplit([0.7, 0.3])
train_df = splits[0]
test_df = splits[1]

# %%
lr = LinearRegression(featuresCol = 'features', labelCol='mean_dew', maxIter=10, regParam=0.3, elasticNetParam=0.8)

# Fit the model
lrModel = lr.fit(train_df)

# Print the coefficients and intercept for linear regression
print("Coefficients: %s" % str(lrModel.coefficients))
print("Intercept: %s" % str(lrModel.intercept))
# Out:
# Coefficients: [1.1761226284214128]
# Intercept: -5.844433868951441

# %%
lr_predictions = lrModel.transform(train_df)
lr_predictions.select("prediction","mean_dew","features").show()
# Out:
# +-------------------+--------+--------+
# |         prediction|mean_dew|features|
# +-------------------+--------+--------+
# |  2.800067449945942|   -0.94|  [7.35]|
# | -8.808262892573401|  -11.04| [-2.52]|
# | -5.162282744467022|   -3.58|  [0.58]|
# |  -9.17286090738404|  -11.02| [-2.83]|
# | -7.561572906446703|   -9.04| [-1.46]|
# | -7.420438191036134|   -8.94| [-1.34]|
# | -6.385450278025291|  -11.81| [-0.46]|
# |-3.3157702178454036|   -5.15|  [2.15]|
# | -4.621266335393171|   -5.91|  [1.04]|
# | -2.610096640792556|   -3.98|  [2.75]|
# |-3.4921886121086154|   -5.19|   [2.0]|
# |-1.4339740123711433|   -3.23|  [3.75]|
# |  1.482810106113961|    3.58|  [6.23]|
# |  0.953554923324325|   -4.64|  [5.78]|
# |  2.882396033935441|    6.36|  [7.42]|
# |-0.7047779827498672|   -8.76|  [4.37]|
# |-0.5518820410550838|  -24.77|   [4.5]|
# |-1.8691393848870659|  -20.19|  [3.38]|
# |-1.6574373117712113|   -0.93|  [3.56]|
# |-1.6339148592027835|   -0.83|  [3.58]|
# +-------------------+--------+--------+
# only showing top 20 rows

# %%
# Summarize the model over the training set and print out some metrics
trainingSummary = lrModel.summary
print("RMSE: %f" % trainingSummary.rootMeanSquaredError)
print("r2: %f" % trainingSummary.r2)
# Out:
# RMSE: 2.564847
# r2: 0.788795

# %%
train_df.describe().show()
# Out:
# +-------+-----------------+
# |summary|         mean_dew|
# +-------+-----------------+
# |  count|              260|
# |   mean|3.616884615384616|
# | stddev|5.591731822457132|
# |    min|           -24.77|
# |    max|            13.81|
# +-------+-----------------+

# %%
lr_predictions = lrModel.transform(test_df)
lr_predictions.select("prediction","mean_dew","features").show()

from pyspark.ml.evaluation import RegressionEvaluator
lr_evaluator = RegressionEvaluator(predictionCol="prediction", \
                 labelCol="mean_dew",metricName="r2")
print("R Squared (R2) on test data = %g" % lr_evaluator.evaluate(lr_predictions))
# Out:
# +--------------------+--------+--------+
# |          prediction|mean_dew|features|
# +--------------------+--------+--------+
# | -0.3519411942234436|   -3.06|  [4.67]|
# | -4.3742805834246745|    -8.5|  [1.25]|
# |  -6.091419620919938|   -6.91| [-0.21]|
# | -12.089645025869142|  -11.65| [-5.31]|
# |  -6.820615650541214|   -8.59| [-0.83]|
# |  -9.302234396510395|  -12.48| [-2.94]|
# |  -3.715651911508684|   -6.35|  [1.81]|
# |   -8.14963422065741|  -11.64| [-1.96]|
# |  -2.904127297897909|   -3.69|   [2.5]|
# | -2.9982171081716222|   -2.85|  [2.42]|
# |  2.1061550991773093|     4.5|  [6.76]|
# |  0.4360609668189035|   -7.55|  [5.34]|
# |  1.0241222810296096|   -7.24|  [5.84]|
# | -2.0455577791502777|  -11.35|  [3.23]|
# |-0.41074732564451377|   -8.47|  [4.62]|
# |   -1.33988420209743|   -2.58|  [3.83]|
# | -3.4451437069717588|   -5.02|  [2.04]|
# | -3.4921886121086154|   -3.76|   [2.0]|
# |  -2.139647589423991|   -2.24|  [3.15]|
# | -1.6103924066343547|     0.6|   [3.6]|
# +--------------------+--------+--------+
# only showing top 20 rows
#
# R Squared (R2) on test data = 0.851609

# %%
test_result = lrModel.evaluate(test_df)
print("Root Mean Squared Error (RMSE) on test data = %g" % test_result.rootMeanSquaredError)
# Out:
# Root Mean Squared Error (RMSE) on test data = 2.44512

# %%
# Viz
# lr_predictions.select("prediction","mean_dew","features").toPandas()
# viz.plot.scatter("mean_dew","features")#
# Out:
# [DenseVector([-0.12]),
#  DenseVector([1.69]),
#  DenseVector([1.85]),
#  DenseVector([2.02]),
#  DenseVector([3.84]),
#  DenseVector([-4.71]),
#  DenseVector([-4.15]),
#  DenseVector([-1.31]),
#  DenseVector([-1.12]),
#  DenseVector([-0.1]),
#  DenseVector([3.18]),
#  DenseVector([-2.35]),
#  DenseVector([-0.15]),
#  DenseVector([1.86]),
#  DenseVector([2.14]),
#  DenseVector([2.14]),
#  DenseVector([3.75]),
#  DenseVector([-1.32]),
#  DenseVector([0.15]),
#  DenseVector([1.42]),
#  DenseVector([2.1]),
#  DenseVector([1.27]),
#  DenseVector([1.33]),
#  DenseVector([1.49]),
#  DenseVector([2.23]),
#  DenseVector([-0.43]),
#  DenseVector([2.97]),
#  DenseVector([3.18]),
#  DenseVector([4.09]),
#  DenseVector([5.37]),
#  DenseVector([6.46]),
#  DenseVector([6.64]),
#  DenseVector([7.21]),
#  DenseVector([7.41]),
#  DenseVector([7.93]),
#  DenseVector([8.12]),
#  DenseVector([8.37]),
#  DenseVector([7.18]),
#  DenseVector([9.23]),
#  DenseVector([9.89]),
#  DenseVector([10.46]),
#  DenseVector([10.64]),
#  DenseVector([11.76]),
#  DenseVector([9.1]),
#  DenseVector([9.18]),
#  DenseVector([9.28]),
#  DenseVector([9.62]),
#  DenseVector([9.93]),
#  DenseVector([12.24]),
#  DenseVector([11.7]),
#  DenseVector([12.29]),
#  DenseVector([13.56]),
#  DenseVector([13.65]),
#  DenseVector([14.21]),
#  DenseVector([11.68]),
#  DenseVector([11.84]),
#  DenseVector([12.3]),
#  DenseVector([13.19]),
#  DenseVector([13.27]),
#  DenseVector([13.3]),
#  DenseVector([13.54]),
#  DenseVector([13.76]),
#  DenseVector([13.83]),
#  DenseVector([15.16]),
#  DenseVector([14.27]),
#  DenseVector([14.35]),
#  DenseVector([14.71]),
#  DenseVector([15.06]),
#  DenseVector([15.66]),
#  DenseVector([12.08]),
#  DenseVector([12.12]),
#  DenseVector([12.29]),
#  DenseVector([13.03]),
#  DenseVector([13.36]),
#  DenseVector([13.51]),
#  DenseVector([14.77]),
#  DenseVector([12.02]),
#  DenseVector([12.2]),
#  DenseVector([14.63]),
#  DenseVector([9.92]),
#  DenseVector([9.94]),
#  DenseVector([10.13]),
#  DenseVector([10.21]),
#  DenseVector([10.32]),
#  DenseVector([11.45]),
#  DenseVector([8.32]),
#  DenseVector([8.67]),
#  DenseVector([9.22]),
#  DenseVector([9.5]),
#  DenseVector([10.06]),
#  DenseVector([10.33]),
#  DenseVector([3.52]),
#  DenseVector([4.48]),
#  DenseVector([4.98]),
#  DenseVector([5.22]),
#  DenseVector([5.24]),
#  DenseVector([5.85]),
#  DenseVector([8.22]),
#  DenseVector([1.55]),
#  DenseVector([3.01]),
#  DenseVector([4.31]),
#  DenseVector([5.06]),
#  DenseVector([5.23]),
#  DenseVector([6.01]),
#  DenseVector([5.49]),
#  DenseVector([5.65]),
#  DenseVector([5.88]),
#  DenseVector([-6.03]),
#  DenseVector([-5.57]),
#  DenseVector([-0.46]),
#  DenseVector([-0.28]),
#  DenseVector([1.27]),
#  DenseVector([3.64]),
#  DenseVector([-10.97]),
#  DenseVector([-1.49]),
#  DenseVector([-1.06]),
#  DenseVector([1.62]),
#  DenseVector([2.21]),
#  DenseVector([-9.13]),
#  DenseVector([-8.18]),
#  DenseVector([-6.95]),
#  DenseVector([-6.82]),
#  DenseVector([-6.63]),
#  DenseVector([-6.13]),
#  DenseVector([-5.43]),
#  DenseVector([1.52]),
#  DenseVector([-8.59]),
#  DenseVector([-4.24]),
#  DenseVector([-3.95]),
#  DenseVector([-2.89]),
#  DenseVector([-0.61]),
#  DenseVector([0.9]),
#  DenseVector([1.06]),
#  DenseVector([2.95]),
#  DenseVector([-5.76]),
#  DenseVector([-2.96]),
#  DenseVector([-0.49]),
#  DenseVector([0.05]),
#  DenseVector([0.49]),
#  DenseVector([0.91]),
#  DenseVector([2.15]),
#  DenseVector([2.99]),
#  DenseVector([4.35]),
#  DenseVector([2.13]),
#  DenseVector([2.36]),
#  DenseVector([3.32]),
#  DenseVector([4.58]),
#  DenseVector([4.91]),
#  DenseVector([6.17]),
#  DenseVector([6.93]),
#  DenseVector([6.98]),
#  DenseVector([7.24]),
#  DenseVector([9.77]),
#  DenseVector([6.4]),
#  DenseVector([8.94]),
#  DenseVector([10.21]),
#  DenseVector([11.25]),
#  DenseVector([11.75]),
#  DenseVector([12.81]),
#  DenseVector([13.62]),
#  DenseVector([13.84]),
#  DenseVector([15.07]),
#  DenseVector([16.63]),
#  DenseVector([16.96]),
#  DenseVector([12.62]),
#  DenseVector([12.64]),
#  DenseVector([12.88]),
#  DenseVector([13.52]),
#  DenseVector([13.89]),
#  DenseVector([14.07]),
#  DenseVector([14.14]),
#  DenseVector([14.86]),
#  DenseVector([16.24]),
#  DenseVector([17.07]),
#  DenseVector([17.68]),
#  DenseVector([17.72]),
#  DenseVector([15.23]),
#  DenseVector([15.44]),
#  DenseVector([15.79]),
#  DenseVector([15.89]),
#  DenseVector([16.18]),
#  DenseVector([16.57]),
#  DenseVector([17.86]),
#  DenseVector([17.91]),
#  DenseVector([18.01]),
#  DenseVector([17.34]),
#  DenseVector([17.59]),
#  DenseVector([17.63]),
#  DenseVector([17.78]),
#  DenseVector([17.9]),
#  DenseVector([18.19]),
#  DenseVector([18.92]),
#  DenseVector([19.11]),
#  DenseVector([13.07]),
#  DenseVector([13.09]),
#  DenseVector([13.55]),
#  DenseVector([13.68]),
#  DenseVector([14.37]),
#  DenseVector([14.83]),
#  DenseVector([15.32]),
#  DenseVector([4.96]),
#  DenseVector([5.46]),
#  DenseVector([6.83]),
#  DenseVector([6.86]),
#  DenseVector([8.11]),
#  DenseVector([8.12]),
#  DenseVector([9.01]),
#  DenseVector([9.76]),
#  DenseVector([-3.17]),
#  DenseVector([2.25]),
#  DenseVector([2.42]),
#  DenseVector([2.81]),
#  DenseVector([2.95]),
#  DenseVector([3.4]),
#  DenseVector([5.6]),
#  DenseVector([-1.98]),
#  DenseVector([-1.3]),
#  DenseVector([-0.89]),
#  DenseVector([0.79]),
#  DenseVector([0.9]),
#  DenseVector([1.61]),
#  DenseVector([-4.67]),
#  DenseVector([-2.04]),
#  DenseVector([-0.93]),
#  DenseVector([-7.09]),
#  DenseVector([-6.64]),
#  DenseVector([-6.45]),
#  DenseVector([-3.88]),
#  DenseVector([-0.82]),
#  DenseVector([-0.03]),
#  DenseVector([-11.05]),
#  DenseVector([-10.9]),
#  DenseVector([-10.88]),
#  DenseVector([-8.27]),
#  DenseVector([-5.19]),
#  DenseVector([-4.82]),
#  DenseVector([-2.94]),
#  DenseVector([-7.02]),
#  DenseVector([-5.99]),
#  DenseVector([-5.84]),
#  DenseVector([-5.56]),
#  DenseVector([-3.23]),
#  DenseVector([-1.96]),
#  DenseVector([-10.72]),
#  DenseVector([-5.0]),
#  DenseVector([-3.23]),
#  DenseVector([-0.71]),
#  DenseVector([-7.97]),
#  DenseVector([-7.55]),
#  DenseVector([-3.29]),
#  DenseVector([-0.42]),
#  DenseVector([-7.95]),
#  DenseVector([-4.81]),
#  DenseVector([-3.55]),
#  DenseVector([-2.41]),
#  DenseVector([-1.34]),
#  DenseVector([2.84]),
#  DenseVector([2.89]),
#  DenseVector([3.13]),
#  DenseVector([3.29]),
#  DenseVector([2.44]),
#  DenseVector([3.25]),
#  DenseVector([3.32]),
#  DenseVector([3.43]),
#  DenseVector([3.72]),
#  DenseVector([4.79]),
#  DenseVector([6.94]),
#  DenseVector([5.47]),
#  DenseVector([6.16]),
#  DenseVector([6.54]),
#  DenseVector([7.65]),
#  DenseVector([4.63]),
#  DenseVector([5.86]),
#  DenseVector([6.12]),
#  DenseVector([6.38]),
#  DenseVector([7.86]),
#  DenseVector([8.0]),
#  DenseVector([9.13]),
#  DenseVector([11.32]),
#  DenseVector([14.08]),
#  DenseVector([8.33]),
#  DenseVector([8.91]),
#  DenseVector([9.76]),
#  DenseVector([10.15]),
#  DenseVector([10.66]),
#  DenseVector([11.58]),
#  DenseVector([11.7]),
#  DenseVector([10.04]),
#  DenseVector([13.6]),
#  DenseVector([14.3]),
#  DenseVector([13.45]),
#  DenseVector([13.52]),
#  DenseVector([13.63]),
#  DenseVector([15.15]),
#  DenseVector([15.31]),
#  DenseVector([14.83]),
#  DenseVector([14.86]),
#  DenseVector([14.95]),
#  DenseVector([15.73]),
#  DenseVector([16.97]),
#  DenseVector([13.42]),
#  DenseVector([13.68]),
#  DenseVector([13.81]),
#  DenseVector([14.02]),
#  DenseVector([14.72]),
#  DenseVector([14.78]),
#  DenseVector([10.77]),
#  DenseVector([13.34]),
#  DenseVector([7.7]),
#  DenseVector([8.51]),
#  DenseVector([9.2]),
#  DenseVector([9.64]),
#  DenseVector([10.1]),
#  DenseVector([10.73]),
#  DenseVector([4.07]),
#  DenseVector([4.93]),
#  DenseVector([5.07]),
#  DenseVector([5.38]),
#  DenseVector([5.53]),
#  DenseVector([9.24]),
#  DenseVector([2.63]),
#  DenseVector([2.97]),
#  DenseVector([3.01]),
#  DenseVector([3.65]),
#  DenseVector([4.28]),
#  DenseVector([4.35]),
#  DenseVector([4.89]),
#  DenseVector([5.48]),
#  DenseVector([-6.75]),
#  DenseVector([-0.85]),
#  DenseVector([3.27]),
#  DenseVector([-4.25]),
#  DenseVector([-3.88]),
#  DenseVector([0.06]),
#  DenseVector([0.81]),
#  DenseVector([1.09]),
#  DenseVector([1.91]),
#  DenseVector([-3.78]),
#  DenseVector([-3.62]),
#  DenseVector([-3.23]),
#  DenseVector([1.08]),
#  DenseVector([2.21]),
#  DenseVector([2.8]),
#  DenseVector([3.31]),
#  DenseVector([-2.01]),
#  DenseVector([-0.78]),
#  DenseVector([-0.71]),
#  DenseVector([-7.23]),
#  DenseVector([-6.55]),
#  DenseVector([-4.07]),
#  DenseVector([-1.7]),
#  DenseVector([-1.46]),
#  DenseVector([-6.72]),
#  DenseVector([-2.78]),
#  DenseVector([-2.06]),
#  DenseVector([-0.6]),
#  DenseVector([-0.53]),
#  DenseVector([-0.49]),
#  DenseVector([0.44]),
#  DenseVector([3.22]),
#  DenseVector([-10.45]),
#  DenseVector([-10.24]),
#  DenseVector([-7.43]),
#  DenseVector([-5.48]),
#  DenseVector([0.13]),
#  DenseVector([-6.03]),
#  DenseVector([-3.82]),
#  DenseVector([-2.15]),
#  DenseVector([-1.8]),
#  DenseVector([0.68]),
#  DenseVector([-0.88]),
#  DenseVector([-0.23]),
#  DenseVector([1.88]),
#  DenseVector([2.28]),
#  DenseVector([2.96]),
#  DenseVector([2.68]),
#  DenseVector([5.2]),
#  DenseVector([6.65]),
#  DenseVector([6.81]),
#  DenseVector([8.58]),
#  DenseVector([9.84]),
#  DenseVector([3.17]),
#  DenseVector([4.9]),
#  DenseVector([7.35]),
#  DenseVector([7.73]),
#  DenseVector([8.61]),
#  DenseVector([9.35]),
#  DenseVector([7.17]),
#  DenseVector([7.64]),
#  DenseVector([9.42]),
#  DenseVector([12.43]),
#  DenseVector([8.66]),
#  DenseVector([9.12]),
#  DenseVector([9.37]),
#  DenseVector([9.52]),
#  DenseVector([10.28]),
#  DenseVector([10.35]),
#  DenseVector([11.13]),
#  DenseVector([11.34]),
#  DenseVector([12.7]),
#  DenseVector([9.14]),
#  DenseVector([9.54]),
#  DenseVector([10.04]),
#  DenseVector([10.44]),
#  DenseVector([10.5]),
#  DenseVector([10.52]),
#  DenseVector([12.15]),
#  DenseVector([13.13]),
#  DenseVector([14.56]),
#  DenseVector([10.31]),
#  DenseVector([10.7]),
#  DenseVector([11.45]),
#  DenseVector([11.76]),
#  DenseVector([11.79]),
#  DenseVector([12.42]),
#  DenseVector([12.55]),
#  DenseVector([13.59]),
#  DenseVector([10.64]),
#  DenseVector([12.05]),
#  DenseVector([12.54]),
#  DenseVector([13.19]),
#  DenseVector([13.41]),
#  DenseVector([13.69]),
#  DenseVector([10.67]),
#  DenseVector([11.88]),
#  DenseVector([12.29]),
#  DenseVector([13.19]),
#  DenseVector([13.37]),
#  DenseVector([13.57]),
#  DenseVector([5.01]),
#  DenseVector([5.91]),
#  DenseVector([6.08]),
#  DenseVector([7.72]),
#  DenseVector([2.63]),
#  DenseVector([4.13]),
#  DenseVector([5.37]),
#  DenseVector([6.42]),
#  DenseVector([6.44]),
#  DenseVector([-1.47]),
#  DenseVector([-1.17]),
#  DenseVector([-1.12]),
#  DenseVector([-0.98]),
#  DenseVector([-0.62]),
#  DenseVector([-0.26]),
#  DenseVector([-0.24]),
#  DenseVector([-0.61]),
#  DenseVector([-0.1]),
#  DenseVector([1.53]),
#  DenseVector([3.91]),
#  DenseVector([0.54]),
#  DenseVector([1.14]),
#  DenseVector([1.76]),
#  DenseVector([3.45]),
#  DenseVector([3.87]),
#  DenseVector([4.52]),
#  DenseVector([4.65]),
#  DenseVector([-2.92]),
#  DenseVector([-2.48]),
#  DenseVector([-1.76]),
#  DenseVector([1.27]),
#  DenseVector([1.76]),
#  DenseVector([-2.85]),
#  DenseVector([-2.84]),
#  DenseVector([-2.78]),
#  DenseVector([-2.22]),
#  DenseVector([-2.22]),
#  DenseVector([-1.94]),
#  DenseVector([-1.83]),
#  DenseVector([-1.71]),
#  DenseVector([-1.51]),
#  DenseVector([-1.17]),
#  DenseVector([-0.27]),
#  DenseVector([1.25]),
#  DenseVector([-2.87]),
#  DenseVector([-2.48]),
#  DenseVector([-1.67]),
#  DenseVector([-1.36]),
#  DenseVector([-0.78]),
#  DenseVector([0.41]),
#  DenseVector([-4.7]),
#  DenseVector([-3.23]),
#  DenseVector([-2.6]),
#  DenseVector([-1.52]),
#  DenseVector([-0.22]),
#  DenseVector([0.46]),
#  DenseVector([0.87]),
#  DenseVector([-6.31]),
#  DenseVector([-6.17]),
#  DenseVector([1.23]),
#  DenseVector([1.95]),
#  DenseVector([-9.0]),
#  DenseVector([-6.77]),
#  DenseVector([-4.37]),
#  DenseVector([-4.25]),
#  DenseVector([-4.1]),
#  DenseVector([-3.64]),
#  DenseVector([-1.5]),
#  DenseVector([-2.24]),
#  DenseVector([-2.19]),
#  DenseVector([-2.0]),
#  DenseVector([-0.96]),
#  DenseVector([-0.57]),
#  DenseVector([-0.1]),
#  DenseVector([1.37]),
#  DenseVector([1.72]),
#  DenseVector([6.02]),
#  DenseVector([6.88]),
#  DenseVector([7.3]),
#  DenseVector([7.87]),
#  DenseVector([2.95]),
#  DenseVector([3.92]),
#  DenseVector([5.21]),
#  DenseVector([5.55]),
#  DenseVector([6.4]),
#  DenseVector([6.66]),
#  DenseVector([7.38]),
#  DenseVector([7.93]),
#  DenseVector([9.22]),
#  DenseVector([9.32]),
#  DenseVector([10.67]),
#  DenseVector([7.85]),
#  DenseVector([8.72]),
#  DenseVector([8.76]),
#  DenseVector([9.09]),
#  DenseVector([9.16]),
#  DenseVector([9.58]),
#  DenseVector([10.07]),
#  DenseVector([10.77]),
#  DenseVector([13.85]),
#  DenseVector([9.5]),
#  DenseVector([9.97]),
#  DenseVector([11.24]),
#  DenseVector([11.78]),
#  DenseVector([11.79]),
#  DenseVector([12.03]),
#  DenseVector([12.14]),
#  DenseVector([12.52]),
#  DenseVector([15.84]),
#  DenseVector([10.03]),
#  DenseVector([10.76]),
#  DenseVector([11.31]),
#  DenseVector([11.54]),
#  DenseVector([12.26]),
#  DenseVector([12.65]),
#  DenseVector([12.72]),
#  DenseVector([13.37]),
#  DenseVector([14.02]),
#  DenseVector([14.15]),
#  DenseVector([9.11]),
#  DenseVector([9.99]),
#  DenseVector([10.68]),
#  DenseVector([12.75]),
#  DenseVector([7.05]),
#  DenseVector([8.7]),
#  DenseVector([9.93]),
#  DenseVector([7.17]),
#  DenseVector([8.39]),
#  DenseVector([8.49]),
#  DenseVector([8.59]),
#  DenseVector([8.98]),
#  DenseVector([9.65]),
#  DenseVector([11.8]),
#  DenseVector([2.33]),
#  DenseVector([2.63]),
#  DenseVector([3.28]),
#  DenseVector([4.93]),
#  DenseVector([5.06]),
#  DenseVector([5.27]),
#  DenseVector([5.59]),
#  DenseVector([5.93]),
#  DenseVector([-1.98]),
#  DenseVector([1.01]),
#  DenseVector([2.09]),
#  DenseVector([2.26]),
#  DenseVector([2.39]),
#  DenseVector([3.0]),
#  DenseVector([4.36]),
#  DenseVector([5.95]),
#  DenseVector([-2.38]),
#  DenseVector([-2.22]),
#  DenseVector([-0.91]),
#  DenseVector([2.18]),
#  DenseVector([2.71]),
#  DenseVector([-5.07]),
#  DenseVector([-3.27]),
#  DenseVector([-1.21]),
#  DenseVector([-1.06]),
#  DenseVector([-0.71]),
#  DenseVector([2.25]),
#  DenseVector([2.33]),
#  DenseVector([3.86]),
#  DenseVector([-7.51]),
#  DenseVector([-3.48]),
#  DenseVector([-2.2]),
#  DenseVector([-11.06]),
#  DenseVector([-10.25]),
#  DenseVector([-7.71]),
#  DenseVector([-4.51]),
#  DenseVector([-2.59]),
#  DenseVector([-2.25]),
#  DenseVector([-0.89]),
#  DenseVector([-0.78]),
#  DenseVector([0.93]),
#  DenseVector([-11.19]),
#  DenseVector([-2.69]),
#  DenseVector([-2.33]),
#  DenseVector([-7.12]),
#  DenseVector([-6.32]),
#  DenseVector([-4.26]),
#  DenseVector([-3.68]),
#  DenseVector([-3.18]),
#  DenseVector([-3.0]),
#  DenseVector([-2.27]),
#  DenseVector([-4.65]),
#  DenseVector([-4.44]),
#  DenseVector([-2.18]),
#  DenseVector([-2.0]),
#  DenseVector([-0.13]),
#  DenseVector([0.56]),
#  DenseVector([0.64]),
#  DenseVector([1.71]),
#  DenseVector([2.18]),
#  DenseVector([2.57]),
#  DenseVector([3.53]),
#  DenseVector([1.13]),
#  DenseVector([1.17]),
#  DenseVector([1.94]),
#  DenseVector([3.2]),
#  DenseVector([3.98]),
#  DenseVector([3.91]),
#  DenseVector([4.48]),
#  DenseVector([6.87]),
#  DenseVector([8.09]),
#  DenseVector([9.88]),
#  DenseVector([6.3]),
#  DenseVector([6.59]),
#  DenseVector([7.72]),
#  DenseVector([9.08]),
#  DenseVector([7.31]),
#  DenseVector([8.5]),
#  DenseVector([9.01]),
#  DenseVector([9.23]),
#  DenseVector([10.84]),
#  DenseVector([11.4]),
#  DenseVector([11.85]),
#  DenseVector([12.26]),
#  DenseVector([12.51]),
#  DenseVector([12.74]),
#  DenseVector([12.82]),
#  DenseVector([14.65]),
#  DenseVector([14.97]),
#  DenseVector([8.66]),
#  DenseVector([12.77]),
#  DenseVector([12.88]),
#  DenseVector([12.93]),
#  DenseVector([13.59]),
#  DenseVector([8.47]),
#  DenseVector([9.6]),
#  DenseVector([9.62]),
#  DenseVector([10.47]),
#  DenseVector([11.75]),
#  DenseVector([7.81]),
#  DenseVector([7.91]),
#  DenseVector([7.98]),
#  DenseVector([8.03]),
#  DenseVector([8.43]),
#  DenseVector([8.92]),
#  DenseVector([9.39]),
#  DenseVector([10.66]),
#  DenseVector([6.08]),
#  DenseVector([6.71]),
#  DenseVector([7.05]),
#  DenseVector([9.71]),
#  DenseVector([9.97]),
#  DenseVector([1.5]),
#  DenseVector([2.79]),
#  DenseVector([4.29]),
#  DenseVector([6.85]),
#  DenseVector([9.72]),
#  DenseVector([9.87]),
#  DenseVector([0.25]),
#  DenseVector([1.01]),
#  DenseVector([1.64]),
#  DenseVector([1.85]),
#  DenseVector([2.29]),
#  DenseVector([-4.2]),
#  DenseVector([-3.4]),
#  DenseVector([-2.54]),
#  DenseVector([-2.49]),
#  DenseVector([-0.7]),
#  DenseVector([-9.73]),
#  DenseVector([-6.9]),
#  DenseVector([-5.51]),
#  DenseVector([-4.98]),
#  DenseVector([-3.01]),
#  DenseVector([-0.83]),
#  DenseVector([-7.24]),
#  DenseVector([-5.75]),
#  DenseVector([-4.33]),
#  DenseVector([-3.41]),
#  DenseVector([-2.22]),
#  DenseVector([0.68]),
#  DenseVector([-5.5]),
#  DenseVector([-4.61]),
#  DenseVector([-3.67]),
#  DenseVector([-3.52]),
#  DenseVector([-2.76]),
#  DenseVector([-1.04]),
#  DenseVector([-0.3]),
#  DenseVector([-6.83]),
#  DenseVector([-4.98]),
#  DenseVector([-4.32]),
#  DenseVector([-3.81]),
#  DenseVector([-3.34]),
#  DenseVector([-2.13]),
#  DenseVector([-1.82]),
#  DenseVector([-1.19]),
#  DenseVector([1.06]),
#  DenseVector([-2.54]),
#  DenseVector([0.3]),
#  DenseVector([0.52]),
#  DenseVector([2.25]),
#  DenseVector([-3.22]),
#  DenseVector([-2.99]),
#  DenseVector([-2.09]),
#  DenseVector([0.75]),
#  DenseVector([0.86]),
#  DenseVector([-5.38]),
#  DenseVector([-3.96]),
#  DenseVector([-3.25]),
#  DenseVector([-2.2]),
#  DenseVector([-1.79]),
#  DenseVector([-1.62]),
#  DenseVector([-1.54]),
#  DenseVector([0.4]),
#  DenseVector([0.14]),
#  DenseVector([1.33]),
#  DenseVector([1.52]),
#  DenseVector([2.04]),
#  DenseVector([2.24]),
#  DenseVector([2.28]),
#  DenseVector([2.42]),
#  DenseVector([2.88]),
#  DenseVector([4.47]),
#  DenseVector([5.32]),
#  DenseVector([5.58]),
#  DenseVector([7.45]),
#  DenseVector([3.74]),
#  DenseVector([4.23]),
#  DenseVector([5.65]),
#  DenseVector([7.38]),
#  DenseVector([7.46]),
#  DenseVector([7.38]),
#  DenseVector([7.73]),
#  DenseVector([8.33]),
#  DenseVector([8.39]),
#  DenseVector([8.02]),
#  DenseVector([8.7]),
#  DenseVector([9.02]),
#  DenseVector([9.12]),
#  DenseVector([10.55]),
#  DenseVector([8.56]),
#  DenseVector([8.65]),
#  DenseVector([8.69]),
#  DenseVector([8.69]),
#  DenseVector([9.33]),
#  DenseVector([10.56]),
#  DenseVector([11.12]),
#  DenseVector([11.86]),
#  DenseVector([7.25]),
#  DenseVector([8.4]),
#  DenseVector([8.71]),
#  DenseVector([9.09]),
#  DenseVector([9.17]),
#  DenseVector([9.99]),
#  DenseVector([10.2]),
#  DenseVector([10.48]),
#  DenseVector([6.08]),
#  DenseVector([6.44]),
#  DenseVector([9.36]),
#  DenseVector([10.01]),
#  DenseVector([4.41]),
#  DenseVector([4.73]),
#  DenseVector([4.79]),
#  DenseVector([5.37]),
#  DenseVector([5.71]),
#  DenseVector([6.96]),
#  DenseVector([8.17]),
#  DenseVector([8.27]),
#  DenseVector([8.63]),
#  DenseVector([8.84]),
#  DenseVector([2.21]),
#  DenseVector([4.27]),
#  DenseVector([4.93]),
#  DenseVector([5.13]),
#  DenseVector([5.19]),
#  DenseVector([5.63]),
#  DenseVector([6.53]),
#  DenseVector([-0.43]),
#  DenseVector([-0.15]),
#  DenseVector([0.79]),
#  DenseVector([2.4]),
#  DenseVector([2.47]),
#  DenseVector([2.6]),
#  DenseVector([3.07]),
#  DenseVector([3.08]),
#  DenseVector([0.76]),
#  DenseVector([1.42]),
#  DenseVector([-6.33]),
#  DenseVector([-6.04]),
#  DenseVector([-1.53]),
#  DenseVector([-8.01]),
#  DenseVector([-4.58]),
#  DenseVector([-4.57]),
#  DenseVector([-4.36]),
#  DenseVector([-2.45]),
#  DenseVector([-2.4]),
#  DenseVector([-0.7]),
#  DenseVector([-1.63]),
#  DenseVector([-8.2]),
#  DenseVector([-6.37]),
#  DenseVector([-6.08]),
#  DenseVector([-1.63]),
#  DenseVector([-0.63]),
#  DenseVector([0.32]),
#  DenseVector([0.42]),
#  DenseVector([2.35]),
#  DenseVector([-2.54]),
#  DenseVector([-2.41]),
#  DenseVector([-1.81]),
#  DenseVector([-0.4]),
#  DenseVector([-0.15]),
#  DenseVector([2.46]),
#  DenseVector([2.52]),
#  DenseVector([-3.63]),
#  DenseVector([-2.13]),
#  DenseVector([-4.05]),
#  DenseVector([-3.51]),
#  DenseVector([-3.32]),
#  DenseVector([-2.22]),
#  DenseVector([-0.99]),
#  DenseVector([-0.72]),
#  DenseVector([0.09]),
#  DenseVector([-1.2]),
#  DenseVector([-1.19]),
#  DenseVector([-0.65]),
#  DenseVector([-0.14]),
#  DenseVector([0.27]),
#  DenseVector([1.09]),
#  DenseVector([4.03]),
#  DenseVector([4.65]),
#  DenseVector([5.08]),
#  DenseVector([7.49]),
#  DenseVector([5.77]),
#  DenseVector([5.95]),
#  DenseVector([7.12]),
#  DenseVector([7.68]),
#  DenseVector([8.9]),
#  DenseVector([9.03]),
#  DenseVector([13.95]),
#  DenseVector([3.85]),
#  DenseVector([4.34]),
#  DenseVector([4.74]),
#  DenseVector([5.08]),
#  DenseVector([5.21]),
#  DenseVector([5.78]),
#  DenseVector([5.96]),
#  DenseVector([6.11]),
#  DenseVector([9.48]),
#  DenseVector([11.57]),
#  DenseVector([11.85]),
#  DenseVector([13.29]),
#  DenseVector([13.71]),
#  DenseVector([15.77]),
#  DenseVector([11.0]),
#  DenseVector([11.7]),
#  DenseVector([11.93]),
#  DenseVector([12.72]),
#  DenseVector([13.19]),
#  DenseVector([13.21]),
#  DenseVector([13.36]),
#  DenseVector([13.37]),
#  DenseVector([15.73]),
#  DenseVector([8.29]),
#  DenseVector([8.55]),
#  DenseVector([8.59]),
#  DenseVector([9.01]),
#  DenseVector([9.5]),
#  DenseVector([9.61]),
#  DenseVector([11.57]),
#  DenseVector([7.85]),
#  DenseVector([8.88]),
#  DenseVector([8.91]),
#  DenseVector([9.48]),
#  DenseVector([10.12]),
#  DenseVector([10.31]),
#  DenseVector([3.11]),
#  DenseVector([4.46]),
#  DenseVector([5.04]),
#  DenseVector([5.14]),
#  DenseVector([8.22]),
#  DenseVector([1.32]),
#  DenseVector([1.55]),
#  DenseVector([2.09]),
#  DenseVector([5.29]),
#  DenseVector([7.19]),
#  DenseVector([8.5]),
#  DenseVector([-0.1]),
#  DenseVector([3.64]),
#  DenseVector([4.07]),
#  DenseVector([4.62]),
#  DenseVector([4.66]),
#  DenseVector([-4.58]),
#  DenseVector([-3.94]),
#  DenseVector([-1.7]),
#  DenseVector([0.08]),
#  DenseVector([1.41]),
#  DenseVector([-1.53]),
#  DenseVector([-1.09]),
#  DenseVector([-1.01]),
#  DenseVector([-8.95]),
#  DenseVector([-7.12]),
#  DenseVector([-6.29]),
#  DenseVector([-5.63]),
#  DenseVector([-5.52]),
#  DenseVector([-5.01]),
#  DenseVector([-1.56]),
#  DenseVector([-0.71]),
#  DenseVector([2.52]),
#  DenseVector([-14.83]),
#  DenseVector([-12.73]),
#  DenseVector([-12.22]),
#  DenseVector([-10.04]),
#  DenseVector([-9.66]),
#  DenseVector([-8.63]),
#  DenseVector([-8.05]),
#  DenseVector([-6.47]),
#  DenseVector([0.33]),
#  DenseVector([-8.76]),
#  DenseVector([-7.67]),
#  DenseVector([-5.44]),
#  DenseVector([-5.11]),
#  DenseVector([-4.5]),
#  DenseVector([-2.44]),
#  DenseVector([-5.6]),
#  DenseVector([-2.58]),
#  DenseVector([-1.8]),
#  DenseVector([-0.32]),
#  DenseVector([-8.44]),
#  DenseVector([-3.7]),
#  DenseVector([-2.98]),
#  DenseVector([-2.6]),
#  DenseVector([-1.77]),
#  DenseVector([-5.79]),
#  DenseVector([-5.42]),
#  DenseVector([-2.75]),
#  DenseVector([-1.43]),
#  DenseVector([2.78]),
#  DenseVector([3.57]),
#  DenseVector([-4.17]),
#  DenseVector([-2.41]),
#  DenseVector([-1.17]),
#  DenseVector([-0.7]),
#  DenseVector([0.57]),
#  DenseVector([1.0]),
#  DenseVector([1.57]),
#  DenseVector([-1.42]),
#  DenseVector([-0.8]),
#  DenseVector([-0.11]),
#  DenseVector([3.64]),
#  DenseVector([4.52]),
#  DenseVector([4.72]),
#  DenseVector([3.86]),
#  DenseVector([4.85]),
#  DenseVector([5.37]),
#  DenseVector([5.64]),
#  DenseVector([6.02]),
#  DenseVector([6.49]),
#  DenseVector([6.71]),
#  DenseVector([9.15]),
#  DenseVector([9.82]),
#  DenseVector([10.49]),
#  DenseVector([6.49]),
#  DenseVector([6.58]),
#  DenseVector([8.0]),
#  DenseVector([9.72]),
#  DenseVector([10.26]),
#  DenseVector([13.11]),
#  DenseVector([13.18]),
#  DenseVector([9.67]),
#  DenseVector([11.62]),
#  DenseVector([14.73]),
#  DenseVector([14.96]),
#  DenseVector([9.02]),
#  DenseVector([9.43]),
#  DenseVector([9.44]),
#  DenseVector([10.8]),
#  DenseVector([11.49]),
#  DenseVector([8.35]),
#  DenseVector([9.4]),
#  ...]

# %% [markdown]
# ## Choses à faire

# %% [markdown]
# 0) Faire valider le 1er modele par Sayf
# 1) Arrondir toutes les valeurs
# 2) Refaire le split (train/test)
# 3) D'autres algos : bataille d'I.A.
# 4) Voir d'autres prédictions prtinentes à faire
